# %% [markdown]
# <a href="https://colab.research.google.com/github/mvgouvea/Google-Colab/blob/main/aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Feito no [Ltspace](https://drive.google.com/file/d/1s9tPiztJc8QuZsIlomoIiaD9gS5wyy7_/view?usp=sharing) agora sendo efetuado no Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Estou pegando o sinal, gera um vetor de vários valores
# - O sinal é o que tem a maior frequencia e menor tempo
# - O tempo final tem que ser metade da portadora
# - Frequencia:
# - Amplitude:
# - Portadora: Está alto a frequencia
# - Sinal: Está baixo
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

#portadora fp
#tempo fm
fp = 80e3; Tp = 1/fp
fm = 1e3; Tm = 1/fm

t = np.arange(0, 2*Tm, Tp/20) # Arange retorna um array que é a grosso modo um vetor
port = np.cos(2*np.pi*fp*t)
info = 0.5*np.cos(2*np.pi*fm*t)
am = info*port

plt.subplots(figsize=(25, 15))
plt.grid()
#plt.plot(t, port)
plt.plot(t, info)
plt.plot(t, am)

#port = np.sin(2* np.pi * fp * t)
#t = np.arange(0, 6e-3, 1e-3/tempo
#plt.plot(t, port) com valor de tempo: 50
